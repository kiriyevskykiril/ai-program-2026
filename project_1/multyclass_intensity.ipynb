# %% [markdown]
# # the idea is to split intensity to multiclasses and than try to predict the intensity calss of the ingredient
#
#
# The LMS is a labeled verbal anchor with a range of 0−100, and the values denote the following: barely detectable, 1.4; weak, 6.1; moderate, 17.2; strong, 35.4; very strong, 53.3; and strongest imaginable, 100.
#
# < 6.1 'barely detectable'
# 6.1 < 17.2 'weak'
# 17.2 < 35.4 'moderate'
# 35.4 < 53.3 'strong'
# 53.3 < 100 'very strong'

# %%
import pandas as pd
