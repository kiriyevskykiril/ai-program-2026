# %%
import pandas as pd

# %%
# reading of crawling results
vp_df = pd.read_csv('data/output_vp_full_v4.csv')
vp_df
# Out:
#       moodifyindex(mi)                   Name of Material         CAS     CID  \
# 0              1000001                       BENZALDEHYDE    100-52-7     240
# 1              1000002                         BOURGEONAL  18127-01-0   64832
# 2              1000003                            CAMPHOR     76-22-2    2537
# 3              1000004                CEDROL METHYL ETHER  19870-74-7   88288
# 4              1000005                         (E)-CITRAL    141-27-5  638011
# ...                ...                                ...         ...     ...
# 2321           1004290            BENZYL VALERATE 10% DPG  10361-39-4   82584
# 2322           1004291                    EUGENOL 10% DPG     97-53-0    3314
# 2323           1004292                    TRIPLAL 10% DPG  68039-49-6   93375
# 2324           1004293             3-METHYLINDOLE 10% DPG     83-34-1    6736
# 2325           1004300  para-tert-butyl phenyl isobutanol  56107-04-1   92013
#
# ...

# %%
vp_df = vp_df[['CID', 'vp_mmhg_pubchem_clean']] # taking only relevant columns
vp_df.dropna(subset=['vp_mmhg_pubchem_clean'], inplace=True) # droping of rows with missing clean values
print(vp_df.shape)
vp_df.rename(columns={'vp_mmhg_pubchem_clean' : 'vp_exp'}, inplace=True)
vp_df
# Out:
# (416, 2)
#         CID     vp_exp
# 0       240   0.997582
# 2      2537   0.202517
# 5       323   0.000980
# 6      3314   0.030000
# 11     8130   3.000000
# ...     ...        ...
# 2310   5416   0.058000
# 2317   8130   3.000000
# 2319  11614  21.751789
# 2320    460   0.103000
# 2322   3314   0.030000
#
# [416 rows x 2 columns]

# %%
# now let's how many experimental values we have in Waka data set for bulding of learning model
waka_df = pd.read_csv("data/waka_with_CID.csv")
waka_df.head()
# Out:
#    Unnamed: 0     CID          CAS                           Name   Imax  \
# 0           0  162268  37609-25-9   (5Z)-cyclohexadec-5-en-1-one   14.50
# 1           1    2758    470-82-6                     1,8-cineol   58.98
# 2           2    8187    112-45-8                   10-undecenal   60.03
# 3           3   18827   3391-86-4                   1-octen-3-ol   41.28
# 4           4   17121    2442-10-6          1-octen-3-yl acetate   54.08
#
#      Ci    Di
# 0 -2.48  0.27
# 1  1.41  0.86
# 2  0.29  0.75
# 3  0.93  0.62
# 4  1.66  0.87

# %%
waka_vp = waka_df.merge(
    vp_df,
    on="CID",
    how='left'    
)

print(
    waka_vp["vp_exp"]
    .notna()
    .sum()
)
# Out:
# 126

# %%
dragon_df = pd.read_csv('data/raw_dragon_matrix.csv')
dragon_df.head()
# Out:
#    CID          MW    AMW      Sv       Se         Sp         Si     Mv  \
# 0  126  122.130000  8.142  10.010  15.3050  10.193000  16.664000  0.667
# 1  176   60.060000  7.507   4.483   8.4220   4.896675   9.249000  0.560
# 2  177   57.375125  6.294   4.483   7.7353   4.896675   8.566025  0.538
# 3  179   88.120000  6.294   7.537  14.1890   7.955000  16.080000  0.538
# 4  180   58.090000  5.809   5.295   9.9780   5.739000  11.455000  0.530
#
#       Me     Mp  ...     VvdwMG     VvdwZAZ    PDI  BLTF96  BLTD48  BLTA96  \
# 0  1.020  0.680  ...  66.806000  113.420000  0.864   -2.37   -2.42   -2.39
# 1  1.053  0.554  ...  36.165462   58.100000  0.684   -1.06   -0.95   -0.84
# 2  1.013  0.568  ...  36.165462   58.069625  0.729   -1.12   -1.02   -0.91
# 3  1.014  0.568  ...  54.205000   92.700000  0.717   -1.20   -1.11   -1.00
# 4  0.998  0.574  ...  40.616000   66.610000  0.766   -1.56   -1.51   -1.43
#
#    nCIR   ZM1  R8u_  nRCOSR
# 0   1.0  40.0   0.0       0
# ...

# %%
# Now, let's proceed with regression  models  attempts to predict the vapor pressure

# merging with dragon df

print(f"Initial shape of vp_df {vp_df.shape}")

vp_dragon_df = pd.merge(
    vp_df,
    dragon_df,
    how='left',
    on='CID',
)

print(f"Initial shape after merging: {vp_dragon_df.shape}")
print(f'Namber of rows withou Dragon values: {vp_dragon_df.isna().any(axis=1).sum()}')

# removing of rows without values
vp_dragon_df = vp_dragon_df.dropna()
print(f'After droping of rows without Dragon values wh have a shape of {vp_dragon_df.shape}')

# I need to delete rows where vp_exp <= 0
vp_dragon_df = vp_dragon_df[vp_dragon_df['vp_exp'] > 0.0]
vp_dragon_df
# Out:
# Initial shape of vp_df (416, 2)
# Initial shape after merging: (416, 2492)
# Namber of rows withou Dragon values: 75
# After droping of rows without Dragon values wh have a shape of (341, 2492)
#        CID     vp_exp      MW    AMW      Sv      Se      Sp      Si     Mv  \
# 0      240   0.997582  106.13  7.581   9.295  13.978   9.739  15.455  0.664
# 1     2537   0.202517  152.26  5.639  14.929  26.396  16.546  30.531  0.553
# 2      323   0.000980  146.15  8.597  12.010  17.305  12.193  18.664  0.706
# 3     3314   0.030000  164.22  6.842  14.590  23.956  15.477  26.910  0.608
# 4     8130   3.000000  114.21  5.191  11.402  21.513  12.784  25.116  0.518
# ..     ...        ...     ...    ...     ...     ...     ...     ...    ...
# 408  11463   0.740000  136.26  5.241  14.214  25.069  16.091  29.322  0.547
# 412   8130   3.000000  114.21  5.191  11.402  21.513  12.784  25.116  0.518
# 413  11614  21.751789  102.15  6.009   9.064  17.073   9.716  19.495  0.533
# ...

# %%
# insure that minimal value is above zero
vp_dragon_df['vp_exp'].min()
# Out:
# np.float64(2.2e-07)

# %%
mX_df_stage0 = vp_dragon_df.loc[:, 'MW':].copy()
vY_ds = vp_dragon_df['vp_exp'].copy()

# %%
# interesting to see how the vapor pressure is destributed
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots(ncols=2, nrows=1, figsize = (12, 6))
ax[0].hist(vY_ds, bins= 30)
ax[0].set_title('Destribution of Vapor pressure values')
ax[0].set_xlabel('Vapor Pressure values in mm Hg')
ax[0].set_ylabel('Sample counts')
ax[1].hist(np.log10(vY_ds), bins= 30)
ax[1].set_title('Destribution of log10(VP)')
ax[1].set_xlabel('Log10(VP)')
ax[1].set_ylabel('Sample counts')

plt.show()

# %%
# let's proceed with cleaning of feture matrix

#first we remove features with zero variance
from sklearn.feature_selection import VarianceThreshold

vt = VarianceThreshold(threshold=0) #object 

mX_stage1 = vt.fit_transform(mX_df_stage0) #returns NDArray

# mX1_df becomes the updated feature matrix
mX_df_stage1 = pd.DataFrame(
    mX_stage1,
    columns=mX_df_stage0.columns[vt.get_support()],
    index=mX_df_stage0.index
)

print(mX_df_stage1.shape)
# Out:
# (340, 2489)

# %%
print(f'The number of reduced features: {(~vt.get_support()).sum()}')
print(f'The features which were removed: {mX_df_stage0.columns[~vt.get_support()]}')
# Out:
# The number of reduced features: 1
# The features which were removed: Index(['nRCOSR'], dtype='str')

# %%
# now we want to reduce the features with high correaltion
# finfing of descriptors with correaltion higher than 0.95

# correlations matrix
corr_matrix = mX_df_stage1.corr().abs()

upper = corr_matrix.where(
    np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
)

to_drop = [
    column
    for column in upper.columns
    if any(upper[column] > 0.95) # May be the correlation threshold should be lower
]

print(f"Descriptors to remove: {len(to_drop)}")
# Out:
# Descriptors to remove: 1675

# %%
# Dropping of high correlated descriptors
mX_df_stage2 = mX_df_stage1.drop(columns=to_drop)
print(mX_df_stage2.shape)
# Out:
# (340, 814)

# %%
mX_df_stage2.shape
# Out:
# (340, 814)

# %%
vY = np.log10(vY_ds)
print(vY.shape)
# Out:
# (340,)

# %%
# Train XGBoost on All reamining descriptors

from xgboost import XGBRegressor

xgb = XGBRegressor(
    n_estimators=1000,
    objective='reg:absoluteerror',
    max_depth=4,
    learning_rate=0.03,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)

xgb.fit(mX_df_stage2, vY)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
importance = pd.Series(
    xgb.feature_importances_,
    index=mX_df_stage2.columns
).sort_values(ascending=False)

# %%
importance.head(60)
# Out:
# MWC03             0.006136
# SM10_AEA_bo_      0.005297
# J_D_Dt            0.005261
# H2m               0.004408
# HATS5m            0.003969
# Eig12_AEA_ed_     0.003866
# ATS8m             0.003671
# TDB06m            0.003552
# SM14_AEA_bo_      0.003532
# GATS7v            0.003472
# Eig04_AEA_dm_     0.003469
# Eig10_AEA_ri_     0.003392
# TDB05s            0.003236
# Mor02m            0.003225
# Wi_Dt             0.003177
# Psi_i_t           0.003107
# SpMaxA_AEA_dm_    0.003103
# WiA_Dt            0.002889
# TDB03v            0.002850
# RDF060m           0.002817
# P_VSA_s_3         0.002784
# R3m               0.002770
# Eig06_AEA_dm_     0.002743
# SpMax6_Bh_m_      0.002658
# ATSC4s            0.002650
# H2v               0.002649
# SpMax4_Bh_s_      0.002622
# RDF050m           0.002565
# MATS1v            0.002535
# Eig04_AEA_bo_     0.002514
# Psi_i_s           0.002427
# R5m_              0.002426
# RDF030m           0.002426
# RTm               0.002379
# ...

# %%
X60 = mX_df_stage2[importance.index[:60]]

# %%
param_grid = {
    "n_estimators": [200, 500, 1000],
    "max_depth": [2, 3, 4],
    "learning_rate": [0.01, 0.03, 0.05],
    "subsample": [0.7, 0.8, 1.0],
    "colsample_bytree": [0.5, 0.7, 0.9],
    "min_child_weight": [1, 3, 5],
    "reg_alpha": [0, 0.01, 0.1],
    "reg_lambda": [1, 3, 10]
}

# %%
from sklearn.model_selection import KFold, cross_val_predict, GridSearchCV

# %%
cv = KFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

grid = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid,
    scoring="neg_mean_absolute_error",
    cv=cv,
    n_jobs=-1,
    verbose=2
)

grid.fit(X60, vY)

print("Best CV MAE:", -grid.best_score_)
print("Best params:")
print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 6561 candidates, totalling 32805 fits
# Best CV MAE: 0.3556234542389084
# Best params:
# {'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 1000, 'reg_alpha': 0.1, 'reg_lambda': 3, 'subsample': 0.8}

# %%
xgb_best = XGBRegressor(
    n_estimators=1000,
    objective='reg:absoluteerror',
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.7,
    min_child_weight= 3,
    random_state=42,
    reg_alpha =0.1,
    reg_lambda= 3,
    n_jobs=-1
)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_absolute_error, r2_score

vY_pred_log = cross_val_predict(
    xgb_best,
    X60,
    vY,
    cv=cv,
    n_jobs=-1
)

vY_pred_mmhg = 10 ** vY_pred_log
vY_true_mmhg = 10 ** vY

mae_log = mean_absolute_error(vY, vY_pred_log)
r2_log = r2_score(vY, vY_pred_log)

mae_mmhg = mean_absolute_error(vY_true_mmhg, vY_pred_mmhg)
r2_mmhg = r2_score(vY_true_mmhg, vY_pred_mmhg)

print("CV MAE log10(VP):", mae_log)
print("R2 for log10(VP):", r2_log)

print("")
print("CV MAE VP mmHg:", mae_mmhg)
print("R2 for VP in mmHg :", r2_mmhg)
# Out:
# CV MAE log10(VP): 0.3556234542389084
# R2 for log10(VP): 0.8556344990905461
#
# CV MAE VP mmHg: 8.904954018041272
# R2 for VP in mmHg : 0.7041704016171976

# %%
fig, ax = plt.subplots(ncols=2, nrows=1, figsize = (12, 6))

ax[0].scatter(vY_true_mmhg, vY_pred_mmhg, alpha=0.5, label = 'VP in mmHg Estimation')
ax[0].plot(vY_true_mmhg, vY_true_mmhg, alpha=0.5, lw=1, linestyle = '--', color='k', label = 'Ground True')
ax[0].set_title('Calculated VP in mmHg from predicted log10(VP)')
ax[0].set_xlabel("True VP in mmHg")
ax[0].set_ylabel("Predicted vP in mmHg")
ax[0].legend()


ax[1].scatter(vY, vY_pred_log, alpha=0.5, label = 'Log10(VP) Estimation')
ax[1].plot(vY, vY, alpha=0.5, lw=1, linestyle = '--', color='k', label='Ground True')
ax[1].set_title('CV XGB prediction of Log10(VP)')
ax[1].set_xlabel("True Log10(VP)")
ax[1].set_ylabel("Predicted Log10(VP)")

ax[1].text(-7.0, 1.85, f"MAE: {mae_log:.2f}")
ax[1].text(-7.0, 1.45, f"R2: {r2_log:.2f}")
ax[1].legend()


plt.show()

# %%
# As a next step i would like to predict log10(VP) for ingredients from Waka data set which missing experimental values with developed model

waka_vp.drop_duplicates(subset='CID', keep='first', inplace=True) #dropping of duplicates on 'CID'ArithmeticError
print("shape of waka_vp: ", waka_vp.shape)

print(f"For waka dataset {waka_vp['vp_exp'].notna().sum()} proper vp_values were retrieved from Punchem")
print(f"{waka_vp['vp_exp'].isna().sum()} is missing")
waka_vp.head(50)
# Out:
# shape of waka_vp:  (312, 8)
# For waka dataset 66 proper vp_values were retrieved from Punchem
# 246 is missing
#     Unnamed: 0       CID           CAS                               Name  \
# 0            0    162268   37609-25-9       (5Z)-cyclohexadec-5-en-1-one
# 1            1      2758     470-82-6                         1,8-cineol
# 3            2      8187     112-45-8                       10-undecenal
# 4            3     18827    3391-86-4                       1-octen-3-ol
# 5            4     17121     2442-10-6              1-octen-3-yl acetate
# 6            5     21895   29895-73-6   2-(phenylmethyl)-1,3-dioxan-5-ol
# 7            6      8821     140-88-5                     2,6-nonadienal
# 8            7   5362833   28069-72-9                     2,6-nonadienol
# 9            8     61031     110-41-8                 2-methyl undecanal
# 10           9     18938    3452-97-9          3,5,5-trimethyl-1-hexanol
# ...

# %%
missing_vp_exp = waka_vp.loc[waka_vp['vp_exp'].isna()][['CID', 'Name']].copy()
missing_vp_exp.shape
# Out:
# (246, 2)

# %%
missing_vp_exp
# Out:
#          CID                               Name
# 0     162268      (5Z)-cyclohexadec-5-en-1-one
# 3       8187                      10-undecenal
# 4      18827                      1-octen-3-ol
# 5      17121              1-octen-3-yl acetate
# 6      21895  2-(phenylmethyl)-1,3-dioxan-5-ol
# ..       ...                                ...
# 364   166523                           troenan
# 365     8186                         undecanal
# 366   163336                      undecavertol
# 367  9855795                         valencene
# 371  5463762                           violiff
#
# [246 rows x 2 columns]

# %%
feat_df = pd.merge(
    missing_vp_exp[['CID']],
    dragon_df,
    on='CID',
    how='left'
)

# %%
X = feat_df[importance.index[:60]]
X
# Out:
#      MWC03  SM10_AEA_bo_   J_D_Dt    H2m  HATS5m  Eig12_AEA_ed_  ATS8m  \
# 0    4.963         1.943  21.4470  0.635   0.065          1.076  2.843
# 1    4.394         1.732  11.0000  0.290   0.021          0.000  1.924
# 2    4.143         1.599   8.0000  0.186   0.036          0.000  0.400
# 3    4.533         1.949  11.0000  0.392   0.064          0.000  1.556
# 4    5.030         2.452   9.6943  0.559   0.071          0.961  1.800
# ..     ...           ...      ...    ...     ...            ...    ...
# 241  5.056         2.718  10.9615  0.364   0.049          1.079  2.128
# 242  4.394         1.732  11.0000  0.287   0.018          0.000  1.952
# 243    NaN           NaN      NaN    NaN     NaN            NaN    NaN
# 244    NaN           NaN      NaN    NaN     NaN            NaN    NaN
# 245  4.779         2.107  11.8606  0.442   0.064          0.447  1.120
#
#      TDB06m  SM14_AEA_bo_  GATS7v  ...    H2s  MATS7v  HATS2u   R3e_   CIC1  \
# ...

# %%
xgb_best.fit(X60, vY)
VP_Pred_waka_miss = xgb_best.predict(X)

# %%
missing_vp_exp['log_vp_predicted'] = VP_Pred_waka_miss
missing_vp_exp
# Out:
#          CID                               Name  log_vp_predicted
# 0     162268      (5Z)-cyclohexadec-5-en-1-one          -2.928578
# 3       8187                      10-undecenal          -1.201890
# 4      18827                      1-octen-3-ol          -0.431004
# 5      17121              1-octen-3-yl acetate          -1.378668
# 6      21895  2-(phenylmethyl)-1,3-dioxan-5-ol          -1.878649
# ..       ...                                ...               ...
# 364   166523                           troenan          -2.020610
# 365     8186                         undecanal          -1.189116
# 366   163336                      undecavertol          -3.911308
# 367  9855795                         valencene          -3.911308
# 371  5463762                           violiff          -2.081275
#
# [246 rows x 3 columns]

# %%
waka_vp
# Out:
#      Unnamed: 0      CID          CAS                           Name   Imax  \
# 0             0   162268  37609-25-9   (5Z)-cyclohexadec-5-en-1-one   14.50
# 1             1     2758    470-82-6                     1,8-cineol   58.98
# 3             2     8187    112-45-8                   10-undecenal   60.03
# 4             3    18827   3391-86-4                   1-octen-3-ol   41.28
# 5             4    17121    2442-10-6          1-octen-3-yl acetate   54.08
# ..          ...      ...          ...                            ...    ...
# 365         309     8186    112-44-7                      undecanal   35.68
# 366         310   163336  81782-77-6                   undecavertol   61.49
# 367         311  9855795    4630-07-3                     valencene   27.03
# 368         312     1183    121-33-5                       vanillin   39.02
# 371         313  5463762  87731-18-8                        violiff   43.25
#
#        Ci    Di    vp_exp
# 0   -2.48  0.27       NaN
# ...

# %%
waka_vp = pd.merge(
    waka_vp,
    missing_vp_exp[['CID', 'log_vp_predicted']],
    how='left',
    on= 'CID'
)

# %%
waka_vp = waka_vp.loc[:, 'CID':]

# %%
waka_vp
# Out:
#          CID          CAS                           Name   Imax    Ci    Di  \
# 0     162268  37609-25-9   (5Z)-cyclohexadec-5-en-1-one   14.50 -2.48  0.27
# 1       2758    470-82-6                     1,8-cineol   58.98  1.41  0.86
# 2       8187    112-45-8                   10-undecenal   60.03  0.29  0.75
# 3      18827   3391-86-4                   1-octen-3-ol   41.28  0.93  0.62
# 4      17121    2442-10-6          1-octen-3-yl acetate   54.08  1.66  0.87
# ..       ...          ...                            ...    ...   ...   ...
# 307     8186    112-44-7                      undecanal   35.68  0.41  0.19
# 308   163336  81782-77-6                   undecavertol   61.49  0.41  0.72
# 309  9855795    4630-07-3                     valencene   27.03  0.96  0.28
# 310     1183    121-33-5                       vanillin   39.02 -1.81  0.00
# 311  5463762  87731-18-8                        violiff   43.25  0.61  0.44
#
#        vp_exp  log_vp_predicted
# ...

# %%
waka_vp['log_vp_exp'] = np.log10(waka_vp['vp_exp'])

# %%
waka_vp
# Out:
#          CID          CAS                           Name   Imax    Ci    Di  \
# 0     162268  37609-25-9   (5Z)-cyclohexadec-5-en-1-one   14.50 -2.48  0.27
# 1       2758    470-82-6                     1,8-cineol   58.98  1.41  0.86
# 2       8187    112-45-8                   10-undecenal   60.03  0.29  0.75
# 3      18827   3391-86-4                   1-octen-3-ol   41.28  0.93  0.62
# 4      17121    2442-10-6          1-octen-3-yl acetate   54.08  1.66  0.87
# ..       ...          ...                            ...    ...   ...   ...
# 307     8186    112-44-7                      undecanal   35.68  0.41  0.19
# 308   163336  81782-77-6                   undecavertol   61.49  0.41  0.72
# 309  9855795    4630-07-3                     valencene   27.03  0.96  0.28
# 310     1183    121-33-5                       vanillin   39.02 -1.81  0.00
# 311  5463762  87731-18-8                        violiff   43.25  0.61  0.44
#
#        vp_exp  log_vp_predicted  log_vp_exp
# ...

# %%
waka_vp['log_vp'] = waka_vp['log_vp_exp'].fillna(waka_vp['log_vp_predicted'])
waka_vp['source'] = np.where(waka_vp['log_vp_exp'].notna(), 'experimental', 'predicted')
waka_vp['vp'] = 10 ** waka_vp['log_vp']

# %%
waka_vp
# Out:
#          CID          CAS                           Name   Imax    Ci    Di  \
# 0     162268  37609-25-9   (5Z)-cyclohexadec-5-en-1-one   14.50 -2.48  0.27
# 1       2758    470-82-6                     1,8-cineol   58.98  1.41  0.86
# 2       8187    112-45-8                   10-undecenal   60.03  0.29  0.75
# 3      18827   3391-86-4                   1-octen-3-ol   41.28  0.93  0.62
# 4      17121    2442-10-6          1-octen-3-yl acetate   54.08  1.66  0.87
# ..       ...          ...                            ...    ...   ...   ...
# 307     8186    112-44-7                      undecanal   35.68  0.41  0.19
# 308   163336  81782-77-6                   undecavertol   61.49  0.41  0.72
# 309  9855795    4630-07-3                     valencene   27.03  0.96  0.28
# 310     1183    121-33-5                       vanillin   39.02 -1.81  0.00
# 311  5463762  87731-18-8                        violiff   43.25  0.61  0.44
#
# ...

# %%
assert (
    waka_vp[['log_vp_exp', 'log_vp_predicted']]
    .notna()
    .any(axis=1)
    .all()
), "Some rows have neither experimental nor predicted vapor pressure"

# %%
waka_vp = waka_vp[['CID', 'Name', 'log_vp', 'vp']].sort_values(by='CID').copy()

# %%
waka_vp
# Out:
#           CID                       Name    log_vp        vp
# 12        179                   acetoin  -0.163905  0.685638
# 40        240              benzaldehyde  -0.001051  0.997582
# 42        244            benzyl alcohol  -1.004329  0.099008
# 89        323                  coumarin  -3.008774  0.000980
# 90        326            cumin aldehyde  -1.254028  0.055715
# ..        ...                        ...       ...       ...
# 199  16070752                    karanal -3.410876  0.000388
# 191  16204527            isocyclocitral  -3.911308  0.000123
# 292  19871663                 terpirosa  -3.911308  0.000123
# 302  44153588  tricyclodecenyl butyrate  -3.239050  0.000577
# 233  57353762           muscenone delta  -2.689690  0.002043
#
# [312 rows x 4 columns]

# %%
waka_vp.to_csv('data/waka_with_imputed_vp.csv', index=False)
