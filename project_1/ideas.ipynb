# %% [markdown]
# optuna more effective package for searching of optimal parameters!
#
# different models Random Forest / XGBOOST / SVC Kernel , take scores, predict class
#
# anomaly detection
#
# clustring very interesting to see how many clusters can be in waka DB according
