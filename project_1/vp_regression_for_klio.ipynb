# %%
import pandas as pd

# %%
vp_df = pd.read_csv('data/output_vp_full_v4.csv')
vp_df = vp_df[['CID', 'vp_mmhg_pubchem_clean']].copy()
vp_df.dropna(subset=['vp_mmhg_pubchem_clean'], inplace=True) #dropping of rows without clean experimental values
vp_df.rename(columns={'vp_mmhg_pubchem_clean' : 'vp_exp'}, inplace=True)
print(f"Number of ingredient with found experimental VP values: {vp_df.shape[0]}")
vp_df.head()
# Out:
# Number of ingredient with found experimental VP values: 416
#      CID    vp_exp
# 0    240  0.997582
# 2   2537  0.202517
# 5    323  0.000980
# 6   3314  0.030000
# 11  8130  3.000000

# %%
klio_df =
